# %%
from bs4 import BeautifulSoup as bs
import requests as req
import glob, json, os, csv, time

# Base URL and API URL for Bukalapak
baseurl = 'https://www.bukalapak.com/u/'
apiurl = 'https://api.bukalapak.com/stores/'

class Bukalapak:
    def __init__(self, username):
        self.username = username
        self.urltoko = baseurl + username
        self.headerbrowser = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:74.0) Gecko/20100101 Firefox/74.0'}
        
        # Send a GET request to the seller's page
        pg_data = req.get(self.urltoko, headers=self.headerbrowser, timeout=3000)
        try:
            if pg_data.status_code == 200:
                soup = bs(pg_data.text, 'html.parser')
                
                # Get the seller's ID
                print("[+] Mengambil id penjual ...")
                self.idseller = soup.find('a', attrs={'data-user-id': True}).get('data-user-id')
                print("[+] Id penjual: " + self.idseller)
                
                # Get the access token for the API
                print("[+] Mengambil access token ...")
                stoken = soup.find_all('script')
                gtoken = str(stoken[4]).replace("<script>localStorage.setItem('bl_token', '", "").replace(
                    "');</script>", "")
                gtoken = json.loads(str(gtoken))
                self.token = gtoken['access_token']
                print("[+] Access token: " + self.token)
                
                # Start grabbing the products
                self.grabproduk()
            else:
                print("[!] Username tidak ditemukan!")
        except Exception as e:
            print(e)
            print("[!] Website down!")
            exit()

    def grabproduk(self):
        print("=== GRABBING PRODUK ===")
        print("[+] Memulai download halaman produk ...")
        print("\x1B[3m" + "(delay 3 detik untuk menghindari anti-spam!)" + "\x1B[0m")
        
        # Get the total number of products from the API
        api = apiurl + str(self.idseller) + '/products?offset=0&limit=50&access_token=' + self.token
        total_product = req.get(api, headers=self.headerbrowser, timeout=3000).json()
        print("[+] Total produk: " + str(total_product['meta']['total']))
        
        # Remove old files
        print("[+] Hapus file lama ...")
        if not os.path.exists("data"):
            os.makedirs("data")
        for filename in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            os.remove(filename)
        for filename in glob.glob(str(self.idseller) + "_bukalapak.csv"):
            os.remove(filename)
        
        # Grab each page of products
        a = 0
        b = 0
        while True:
            print("-> download halaman ke-" + str(b + 1))
            api = apiurl + str(self.idseller) + '/products?offset=' + str(a) + '&limit=50&access_token=' + self.token
            pg_data = req.get(api, headers=self.headerbrowser, timeout=3000).json()
            
            # If there are no more products, break the loop
            if len(pg_data['data']) == 0:
                break
            
            # Save the product data to a JSON file
            with open("data/" + str(self.idseller) + "_bukalapak" + str(b) + ".json", 'w') as json_file:
                json.dump(pg_data['data'], json_file)
            
            # Increment offsets and wait for 3 seconds to avoid anti-spam measures
            a += 50
            b += 1
            time.sleep(3)
        
        # Merge all JSON files into one
        print("[+] Merging data produk ...")
        data = []
        for f in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            with open(f) as infile:
                data.extend(json.load(infile))
        with open("data/" + str(self.idseller) + "_bukalapak_all.json", 'w') as outfile:
            json.dump(data, outfile)
        
        # Create a CSV file with the product data
        print("[+] Membuat csv data produk ...")
        f_data = []
        for i in data:
            f_data.append([
                self.idseller,
                self.username,
                i['store']['name'],
                i['store']['level']['name'],
                i['store']['premium_level'],
                i['id'],
                i['name'],
                i['category']['name'],
                i['condition'],
                i['rating']['average_rate'],
                i['rating']['user_count'],
                i['stock'],
                i['stats']['interest_count'],
                i['stats']['sold_count'],
                i['stats']['view_count'],
                i['price'],
                i['original_price'],
                i['discount_percentage'],
                i['description']
            ])
        
        f_header = [
            'id_seller', 'username', 'nama_toko', 'level_toko', 'premium_toko', 'id_produk', 'nama_produk',
            'kategori', 'kondisi', 'rating', 'jumlah_rating', 'stok', 'jumlah_interest', 'jumlah_sold',
            'jumlah_view', 'harga', 'harga_asli', 'diskon', 'deskripsi'
        ]
        
        with open(str(self.idseller) + '_bukalapak.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(f_header)
            writer.writerows(f_data)
        
        print('done! ' + str(self.idseller) + '_bukalapak.csv')


print("[+] https://github.com/heryandp/bukalapak-product-scrap")
sname = input("[+] Masukkan username seller: https://www.bukalapak.com/u/")
act = Bukalapak(sname)
# Out:
# [+] https://github.com/heryandp/bukalapak-product-scrap
# [+] Masukkan username seller: https://www.bukalapak.com/u/rakkipanda_id_526115
# [+] Mengambil id penjual ...
# [+] Id penjual: 571925300
# [+] Mengambil access token ...
# [+] Access token: eyJhbGciOiJSUzI1NiIsImtpZCI6ImFjY291bnRzLmp3dC5hY2Nlc3MtdG9rZW4iLCJ0eXAiOiJKV1QifQ.....jXHuQZe83ZO-3FZu141qzcVKXM90hth1xV08qepwHqEwEXhI_safW9UHM76c1F0m4kL-ez_FC8ANRxewqrPbjJc_Q1NJP9o8reLwwktXjzDacEpbb0jubu0Pl0VBCCcJ-gslBqYNWVXUuXgDXKVtq-doZH0dz4TVedkx1KLFaaogtCLKMwQ6AsOOyqWheCqzwjU7oYTKYddT6VeK22HvzvBFLTXaJNZOH1i6ijTldfumhcpUY5pjXwks9DzRCljI-ggkYznpOUhw_Wu9R2H2OaQnX4hmpJoOyKdxyGiOe_reUQ8LV0pBrNVq5qKjRzTmDLhMTMOOmtv6j062ERKrTw
# === GRABBING PRODUK ===
# [+] Memulai download halaman produk ...
# (delay 3 detik untuk menghindari anti-spam!)
# [+] Total produk: 191
# [+] Hapus file lama ...
# -> download halaman ke-1
# -> download halaman ke-2
# -> download halaman ke-3
# -> download halaman ke-4
# -> download halaman ke-5
# [+] Merging data produk ...
# [+] Membuat csv data produk ...
# done! 571925300_bukalapak.csv

# %%
import pandas as pd

data= pd.read_csv('571925300_bukalapak.csv')

display(data.head(50))
# Out:
#     id_seller              username      nama_toko      level_toko  \
# 0   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 1   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 2   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 3   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 4   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 5   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 6   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 7   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 8   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 9   571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 10  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 11  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 12  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 13  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 14  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 15  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 16  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 17  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 18  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 19  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 20  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 21  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 22  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 23  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 24  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 25  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 26  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 27  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 28  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 29  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 30  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 31  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 32  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 33  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 34  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 35  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 36  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 37  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 38  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 39  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 40  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 41  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 42  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 43  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 44  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 45  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 46  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 47  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 48  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
# 49  571925300  rakkipanda_id_526115  rakkipanda id  Pedagang Besar
#
#    premium_toko id_produk                                        nama_produk  \
# 0      platinum   4hni80j  RakkiPanda - Baterai Cas isi Ulang AA USB  Plu...
# 1      platinum   4hnerba  RakkiPanda - HB3447A9EBW Huawei P8 Batre Batra...
# 2      platinum   4hnera1  RakkiPanda - B-W1 Vivo Y02 / Y16 Batre Batrai ...
# 3      platinum   4hnaxya  RakkiPanda - B-T6 Vivo Y75 5G / T1 5G Batre Ba...
# 4      platinum   4hnaxu7  RakkiPanda - BM4P Redmi K30 / Pocophone X2 Bat...
# 42     platinum   4hjzgkd                        Obeng dan Opening tools set
# 43     platinum   4hjtw07  RakkiPanda - Baterai EB-BG781ABY SAMSUNG S20 F...
# 44     platinum   4hjbkij  RakkiPanda - Baterai BM4Q Xiaomi K30 Pro / Poc...
# 45     platinum   4hjbkem             RakkiPanda - Baterai B-G3 Vivo X27 Pro
# 46     platinum   4hjbk6a  RakkiPanda - Baterai B-S1 Vivo Y21 2020 / Y21S...
# 47     platinum   4hihcoa  RakkiPanda - Baterai BJ700BBC Samsung Galaxy J...
# 48     platinum   4hihbnj  RakkiPanda - Baterai EB-BJ120BE Samsung Galaxy...
# 49     platinum   4hihbhd  RakkiPanda - Baterai EB-BJ110ABE Samsung Galax...
#
#                         kategori kondisi  rating  jumlah_rating  stok  \
# 0                        Baterai    Baru     0.0              0   100
# 1                        Baterai    Baru     0.0              0    49
# 2                        Baterai    Baru     0.0              0    49
# 3                        Baterai    Baru     0.0              0    50
# 4                        Baterai    Baru     0.0              0    50
# 5                        Baterai    Baru     0.0              0    50
# 6                        Baterai    Baru     0.0              0    50
# 7                        Baterai    Baru     0.0              0    50
# 8                   Lakban & Lem    Baru     0.0              0   100
# 9                        Baterai    Baru     0.0              0    50
# 10                       Baterai    Baru     0.0              0    30
# 11                       Baterai    Baru     0.0              0    29
# 12                       Baterai    Baru     0.0              0    50
# 13                       Baterai    Baru     0.0              0    49
# 14                       Baterai    Baru     0.0              0    20
# 15                       Baterai    Baru     0.0              0    10
# 16                       Baterai    Baru     0.0              0   100
# 17                       Baterai    Baru     0.0              0    50
# 18                       Baterai    Baru     0.0              0    50
# 19                       Baterai    Baru     0.0              0    50
# 20                       Baterai    Baru     0.0              0    50
# 21                       Baterai    Baru     0.0              0    50
# 22                       Baterai    Baru     0.0              0    50
# 23                       Baterai    Baru     0.0              0    50
# 24                       Baterai    Baru     0.0              0    50
# 25                       Baterai    Baru     0.0              0    50
# 26                       Baterai    Baru     0.0              0    50
# 27                       Baterai    Baru     0.0              0    49
# 28                       Baterai    Baru     0.0              0    50
# 29                       Baterai    Baru     0.0              0    50
# 30                       Baterai    Baru     0.0              0    50
# 31                       Baterai    Baru     0.0              0    50
# 32                       Baterai    Baru     0.0              0    50
# 33                       Baterai    Baru     0.0              0    50
# 34                       Baterai    Baru     0.0              0   100
# 35                       Baterai    Baru     0.0              0    10
# 36                       Baterai    Baru     0.0              0    20
# 37                       Baterai    Baru     0.0              0    10
# 38                       Baterai    Baru     0.0              0    30
# 39                       Baterai    Baru     0.0              0    30
# 40                       Baterai    Baru     0.0              0    29
# 41                       Baterai    Baru     0.0              0    28
# 42  Spare Part & Tools Handphone    Baru     0.0              0    50
# 43                       Baterai    Baru     0.0              0    50
# 44                       Baterai    Baru     0.0              0    50
# 45                       Baterai    Baru     0.0              0   100
# 46                       Baterai    Baru     0.0              0    10
# 47                       Baterai    Baru     0.0              0   100
# 48                       Baterai    Baru     0.0              0   100
# 49                       Baterai    Baru     5.0              1    99
#
#     jumlah_interest  jumlah_sold  jumlah_view   harga  harga_asli  diskon  \
# 0                 0            0            0  190000      190000       0
# 1                 0            0            0  105500      105500       0
# 2                 0            0            0  145000      145000       0
# 3                 0            0            0  159000      159000       0
# 4                 0            0            0  179000      179000       0
# 5                 0            0            0  142500      142500       0
# 6                 0            0            0  221000      221000       0
# 7                 0            0            0  349000      349000       0
# 8                 0            0            0    1250        1250       0
# 9                 0            0            0  157500      157500       0
# 10                0            0            0  157500      157500       0
# 11                0            0            0  145000      145000       0
# 12                0            0            0  157500      157500       0
# 13                1            0            0  157500      157500       0
# 14                0            0            0  155000      155000       0
# 15                0            0            0   93500       93500       0
# 16                0            0            0   40000       40000       0
# 17                0            0            0   59500       59500       0
# 18                0            0            0  125000      125000       0
# 19                0            0            0  155000      155000       0
# 20                0            0            0   81000       81000       0
# 21                0            0            0  150000      150000       0
# 22                0            0            0  117000      117000       0
# 23                0            0            0  130000      130000       0
# 24                0            0            0  157500      157500       0
# 25                1            0            0  125000      125000       0
# 26                0            0            0  150000      150000       0
# 27                0            0            0  155000      155000       0
# 28                0            0            0  155000      155000       0
# 29                0            0            0  150000      150000       0
# 30                0            0            0  425000      425000       0
# 31                0            0            0  295000      295000       0
# 32                0            0            0  295000      295000       0
# 33                0            0            0  275000      275000       0
# 34                0            0            0   33500       33500       0
# 35                0            0            0  145000      145000       0
# 36                0            0            0  145000      145000       0
# 37                0            0            0  125000      125000       0
# 38                0            0            0  123000      123000       0
# 39                0            0            0  145000      145000       0
# 40                0            0            0  123000      123000       0
# 41                0            0            0  150000      150000       0
# 42                2            0            0    3000        3000       0
# 43                0            0            0  149000      149000       0
# 44                0            0            0  175000      175000       0
# 45                0            0            0  125000      125000       0
# 46                0            0            0  140000      140000       0
# 47                0            0            0   77000       77000       0
# 48                0            0            0   65000       65000       0
# 49                1            1            0   65000       65000       0
#
#                                             deskripsi
# 0   <p>RAKKIPANDA AA USB PLUG IN DIRECT BATERAI,  ...
# 1   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 2   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 3   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 4   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 5   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 6   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 7   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 8   <p>Lem Baterai Stiker Adhesive Universal</p><u...
# 9   <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 10  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 11  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 12  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 13  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 14  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 15  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 16  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 17  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 18  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 19  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 20  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 21  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 22  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 23  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 24  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 25  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 26  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 27  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 28  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 29  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 30  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 31  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 32  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 33  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 34  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 35  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 36  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 37  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 38  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 39  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 40  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 41  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 42  <p>Perlatan reparasi smartphone dengan 9 peral...
# 43  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 44  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 45  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 46  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 47  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 48  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...
# 49  <p>Barang Asli, Baru dan Bergaransi Resmi (Gra...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("571925300_bukalapak.csv")

# Selecting the first 50 data points
data_subset = data.head(52)

# Scatter plot with 'rating' against 'jumlah_rating'
plt.scatter(data_subset['rating'], data_subset['jumlah_rating'])

# Adding title to the plot
plt.title("Scatter plot Toko  rakkipanda")

# Setting the x and y labels
plt.xlabel('rating')
plt.ylabel('jumlah_rating')

# Save the plot as a PNG file
plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# reading the database
data = pd.read_csv("571925300_bukalapak.csv")

# Mengambil hanya 50 data pertama
data_52 = data.head(52)

# Line plot dengan jumlah_sold dan kategori
plt.plot(data_52['rating'])
plt.plot(data_52['jumlah_rating'])

# Menambahkan judul pada plot
plt.title("")

# Mengatur label sumbu X dan Y
plt.ylabel('jumlah_rating')
plt.xlabel('rating')

# Save the plot as a PNG file
plt.savefig('line_chart.png', dpi=300, bbox_inches='tight')

plt.show()
